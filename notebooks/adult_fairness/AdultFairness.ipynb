# %% [markdown]
# # Practical Issues
#
# In this notebook we'll go through the process of scanning a model with more production-like characteristics.
# Specifically we'll show how to deal with:
#
# 1. Dataset one-hot encoding by ETL pipelines
# 2. Bucketing numeric features to define fairness groups

# %%
import pandas as pd
import matplotlib as plt
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.pipeline import Pipeline
import numpy as np
import random
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn import svm
from copy import copy

from certifai.scanner.builder import (CertifaiScanBuilder, CertifaiPredictorWrapper, CertifaiModel, CertifaiModelMetric,
                                      CertifaiDataset, CertifaiGroupingFeature, CertifaiDatasetSource,
                                      CertifaiPredictionTask, CertifaiTaskOutcomes, CertifaiOutcomeValue,
                                      CertifaiGroupingBucket)
from certifai.scanner.report_utils import scores, construct_scores_dataframe
from certifai.common.utils.encoding import CatEncoder

# %% [markdown]
# ## Dataset and ETL
#
# We'll use the 'adult income' dataset, and build a simple model to predict whether an individual earns more or
# less than $50k.
#
# In a production setting, models may often be trained from previously pre-processed data, so to simulate this
# we'll first pre-process the dataset to encode its categorical features as one-hots, and save off that pre-processed data, which we'll then go on to use to both train a model and subsequently analyse that model using
# Certifai.

# %%
# Example will use a simple logistic classifier on the German Credit dataset
base_path = '..'
all_data_file = f"{base_path}/datasets/adult_income_eval.csv"
preprocessed_dataset_file = "preprocessed.csv"

df = pd.read_csv(all_data_file)

display(df[:2])

# Encode the categorical columns as one-hots
cat_columns = [
    'workclass',
    'education',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'gender',
    'native-country'
    ]
label_column = 'income'

encoded_df = pd.get_dummies(df, columns=cat_columns)

display(encoded_df[:2])

# We will also want to know how the categorical encoding has mapped categorical values to columns, so
# save this as a dictionary for later use (if the data were given to us pre-encoded then we'd need
# to construct this mapping manually based on manual analysis of the data or a schema definition also given
# to us with the dataset)
cat_value_mappings = {}
for feature in cat_columns:
    one_hot_col_name_prefix = f"{feature}_"
    mapping = {}
    for ec in encoded_df.columns:
        if ec.startswith(one_hot_col_name_prefix):
            value = ec[len(one_hot_col_name_prefix):]
            mapping[value] = ec
    cat_value_mappings[feature] = mapping
    print(f"Feature value -> column mappings for categorical feature '{feature}':")
    for val, col in cat_value_mappings[feature].items():
        print(f"\t{col} -> {val}")

# Save the pre-processed data
encoded_df.to_csv(preprocessed_dataset_file, index=False)
# Out:
#    age          workclass  fnlwgt          education  educational-num  \
# 0   25  workclass_Private  226802     education_11th                7
# 1   38  workclass_Private   89814  education_HS-grad                9
#
#                       marital-status                    occupation  \
# 0       marital-status_Never-married  occupation_Machine-op-inspct
# 1  marital-status_Married-civ-spouse    occupation_Farming-fishing
#
#              relationship        race       gender  capital-gain  \
# 0  relationship_Own-child  race_Black  gender_Male             0
# 1    relationship_Husband  race_White  gender_Male             0
#
#    capital-loss  hours-per-week                native-country  income
# 0             0              40  native-country_United-States       0
# 1             0              50  native-country_United-States       0
#    age  fnlwgt  educational-num  capital-gain  capital-loss  hours-per-week  \
# 0   25  226802                7             0             0              40
# 1   38   89814                9             0             0              50
#
#    income  workclass_workclass_Federal-gov  workclass_workclass_Local-gov  \
# 0       0                                0                              0
# 1       0                                0                              0
#
#    workclass_workclass_Never-worked  ...  \
# 0                                 0  ...
# 1                                 0  ...
#
#    native-country_native-country_Puerto-Rico  \
# 0                                          0
# 1                                          0
#
#    native-country_native-country_Scotland  \
# 0                                       0
# 1                                       0
#
#    native-country_native-country_South  native-country_native-country_Taiwan  \
# 0                                    0                                     0
# 1                                    0                                     0
#
#    native-country_native-country_Thailand  \
# 0                                       0
# 1                                       0
#
#    native-country_native-country_Trinadad&Tobago  \
# 0                                              0
# 1                                              0
#
#    native-country_native-country_United-States  \
# 0                                            1
# 1                                            1
#
#    native-country_native-country_Vietnam  \
# 0                                      0
# 1                                      0
#
#    native-country_native-country_Yugoslavia  \
# 0                                         0
# 1                                         0
#
#    native-country_native-country_unknown
# 0                                      0
# 1                                      0
#
# [2 rows x 109 columns]
# Feature value -> column mappings for categorical feature 'workclass':
# 	workclass_workclass_Federal-gov -> workclass_Federal-gov
# 	workclass_workclass_Local-gov -> workclass_Local-gov
# 	workclass_workclass_Never-worked -> workclass_Never-worked
# 	workclass_workclass_Private -> workclass_Private
# 	workclass_workclass_Self-emp-inc -> workclass_Self-emp-inc
# 	workclass_workclass_Self-emp-not-inc -> workclass_Self-emp-not-inc
# 	workclass_workclass_State-gov -> workclass_State-gov
# 	workclass_workclass_Without-pay -> workclass_Without-pay
# 	workclass_workclass_unknown -> workclass_unknown
# Feature value -> column mappings for categorical feature 'education':
# 	education_education_10th -> education_10th
# 	education_education_11th -> education_11th
# 	education_education_12th -> education_12th
# 	education_education_1st-4th -> education_1st-4th
# 	education_education_5th-6th -> education_5th-6th
# 	education_education_7th-8th -> education_7th-8th
# 	education_education_9th -> education_9th
# 	education_education_Assoc-acdm -> education_Assoc-acdm
# 	education_education_Assoc-voc -> education_Assoc-voc
# 	education_education_Bachelors -> education_Bachelors
# 	education_education_Doctorate -> education_Doctorate
# 	education_education_HS-grad -> education_HS-grad
# 	education_education_Masters -> education_Masters
# 	education_education_Preschool -> education_Preschool
# 	education_education_Prof-school -> education_Prof-school
# 	education_education_Some-college -> education_Some-college
# Feature value -> column mappings for categorical feature 'marital-status':
# 	marital-status_marital-status_Divorced -> marital-status_Divorced
# 	marital-status_marital-status_Married-AF-spouse -> marital-status_Married-AF-spouse
# 	marital-status_marital-status_Married-civ-spouse -> marital-status_Married-civ-spouse
# 	marital-status_marital-status_Married-spouse-absent -> marital-status_Married-spouse-absent
# 	marital-status_marital-status_Never-married -> marital-status_Never-married
# 	marital-status_marital-status_Separated -> marital-status_Separated
# 	marital-status_marital-status_Widowed -> marital-status_Widowed
# Feature value -> column mappings for categorical feature 'occupation':
# 	occupation_occupation_Adm-clerical -> occupation_Adm-clerical
# 	occupation_occupation_Armed-Forces -> occupation_Armed-Forces
# 	occupation_occupation_Craft-repair -> occupation_Craft-repair
# 	occupation_occupation_Exec-managerial -> occupation_Exec-managerial
# 	occupation_occupation_Farming-fishing -> occupation_Farming-fishing
# 	occupation_occupation_Handlers-cleaners -> occupation_Handlers-cleaners
# 	occupation_occupation_Machine-op-inspct -> occupation_Machine-op-inspct
# 	occupation_occupation_Other-service -> occupation_Other-service
# 	occupation_occupation_Priv-house-serv -> occupation_Priv-house-serv
# 	occupation_occupation_Prof-specialty -> occupation_Prof-specialty
# 	occupation_occupation_Protective-serv -> occupation_Protective-serv
# 	occupation_occupation_Sales -> occupation_Sales
# 	occupation_occupation_Tech-support -> occupation_Tech-support
# 	occupation_occupation_Transport-moving -> occupation_Transport-moving
# 	occupation_occupation_unknown -> occupation_unknown
# Feature value -> column mappings for categorical feature 'relationship':
# 	relationship_relationship_Husband -> relationship_Husband
# 	relationship_relationship_Not-in-family -> relationship_Not-in-family
# 	relationship_relationship_Other-relative -> relationship_Other-relative
# 	relationship_relationship_Own-child -> relationship_Own-child
# 	relationship_relationship_Unmarried -> relationship_Unmarried
# 	relationship_relationship_Wife -> relationship_Wife
# Feature value -> column mappings for categorical feature 'race':
# 	race_race_Amer-Indian-Eskimo -> race_Amer-Indian-Eskimo
# 	race_race_Asian-Pac-Islander -> race_Asian-Pac-Islander
# 	race_race_Black -> race_Black
# 	race_race_Other -> race_Other
# 	race_race_White -> race_White
# Feature value -> column mappings for categorical feature 'gender':
# 	gender_gender_Female -> gender_Female
# 	gender_gender_Male -> gender_Male
# Feature value -> column mappings for categorical feature 'native-country':
# 	native-country_native-country_Cambodia -> native-country_Cambodia
# 	native-country_native-country_Canada -> native-country_Canada
# 	native-country_native-country_China -> native-country_China
# 	native-country_native-country_Columbia -> native-country_Columbia
# 	native-country_native-country_Cuba -> native-country_Cuba
# 	native-country_native-country_Dominican-Republic -> native-country_Dominican-Republic
# 	native-country_native-country_Ecuador -> native-country_Ecuador
# 	native-country_native-country_El-Salvador -> native-country_El-Salvador
# 	native-country_native-country_England -> native-country_England
# 	native-country_native-country_France -> native-country_France
# 	native-country_native-country_Germany -> native-country_Germany
# 	native-country_native-country_Greece -> native-country_Greece
# 	native-country_native-country_Guatemala -> native-country_Guatemala
# 	native-country_native-country_Haiti -> native-country_Haiti
# 	native-country_native-country_Holand-Netherlands -> native-country_Holand-Netherlands
# 	native-country_native-country_Honduras -> native-country_Honduras
# 	native-country_native-country_Hong -> native-country_Hong
# 	native-country_native-country_Hungary -> native-country_Hungary
# 	native-country_native-country_India -> native-country_India
# 	native-country_native-country_Iran -> native-country_Iran
# 	native-country_native-country_Ireland -> native-country_Ireland
# 	native-country_native-country_Italy -> native-country_Italy
# 	native-country_native-country_Jamaica -> native-country_Jamaica
# 	native-country_native-country_Japan -> native-country_Japan
# 	native-country_native-country_Laos -> native-country_Laos
# 	native-country_native-country_Mexico -> native-country_Mexico
# 	native-country_native-country_Nicaragua -> native-country_Nicaragua
# 	native-country_native-country_Outlying-US(Guam-USVI-etc) -> native-country_Outlying-US(Guam-USVI-etc)
# 	native-country_native-country_Peru -> native-country_Peru
# 	native-country_native-country_Philippines -> native-country_Philippines
# 	native-country_native-country_Poland -> native-country_Poland
# 	native-country_native-country_Portugal -> native-country_Portugal
# 	native-country_native-country_Puerto-Rico -> native-country_Puerto-Rico
# 	native-country_native-country_Scotland -> native-country_Scotland
# 	native-country_native-country_South -> native-country_South
# 	native-country_native-country_Taiwan -> native-country_Taiwan
# 	native-country_native-country_Thailand -> native-country_Thailand
# 	native-country_native-country_Trinadad&Tobago -> native-country_Trinadad&Tobago
# 	native-country_native-country_United-States -> native-country_United-States
# 	native-country_native-country_Vietnam -> native-country_Vietnam
# 	native-country_native-country_Yugoslavia -> native-country_Yugoslavia
# 	native-country_native-country_unknown -> native-country_unknown

# %% [markdown]
# ## Model training
#
# Now we'll train a model on the pre-processed data.  Re-read from the saved file just to be illustrative here
# since normally we would not already have it loaded in the same notebook or process.
#
# *Note* - This is quite a sizeable dataset, so in the interests of having an illustration that doesn't take too long we'll sub-sample and train on that.

# %%
df = pd.read_csv(preprocessed_dataset_file)

# Sub-sample for training the models
df = df.sample(n=5000)

# Separate outcome
label_column = 'income'

y = df[label_column]
X = df.drop(label_column, axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

def build_model(data, name, model_family, test=None):
    if test is None:
        test = data
    
    # We'll unit scale everything
    def scaled_model(model):      
        scaler = preprocessing.StandardScaler()
        return Pipeline([('scaler', scaler), (model_family, model)])
        
    if model_family == 'SVM':
        parameters = {'SVM__kernel':('linear', 'rbf', 'poly'), 'SVM__C':[0.1, .5, 1, 2, 4, 10], 'SVM__gamma':['auto']}
        m = scaled_model(svm.SVC())
    elif model_family == 'logistic':
        parameters = {'logistic__C': (0.5, 1.0, 2.0), 'logistic__solver': ['lbfgs'], 'logistic__max_iter': [1000]}
        m = scaled_model(LogisticRegression())
    model = GridSearchCV(m, parameters, cv=3)
    model.fit(data[0], data[1])

    # Assess on the test data
    accuracy = model.score(test[0], test[1].values)
    print(f"Model '{name}' accuracy is {accuracy}")
    return model

svm_model = build_model((X_train.values, y_train),
                        'Support Vector Machine',
                        'SVM',
                        test=(X_test.values, y_test))

logistic_model = build_model((X_train.values, y_train),
                        'Logistic classifier',
                        'logistic',
                        test=(X_test.values, y_test))
# Out:
# Model 'Support Vector Machine' accuracy is 0.866
# Model 'Logistic classifier' accuracy is 0.858

# %% [markdown]
# ## Analyze for fairness
#
# Now we'll perform a Certifai scan to analyze our models for bias with respect to age.
#
# Since age is a numeric feature with granular values, we'll bucket it into ranges for the fairness
# analysis of '<25', '25-49', '50+'

# %%
# Wrap the model up for use by Certifai as a local model
svm_model_proxy = CertifaiPredictorWrapper(svm_model)
logistic_model_proxy = CertifaiPredictorWrapper(logistic_model)

# %%
# Create the scan object from scratch using the ScanBuilder class

# First define the possible prediction outcomes
task = CertifaiPredictionTask(CertifaiTaskOutcomes.classification(
    [
        CertifaiOutcomeValue(1, name='High income', favorable=True),
        CertifaiOutcomeValue(0, name='Low income')
    ]),
    prediction_description="Determine whether an individual's income is > $50k")

scan = CertifaiScanBuilder.create('test_user_case',
                                  prediction_task=task)

# Add our local models
first_model = CertifaiModel('SVM',
                            local_predictor=svm_model_proxy)
scan.add_model(first_model)
second_model = CertifaiModel('logistic',
                            local_predictor=logistic_model_proxy)
scan.add_model(second_model)

# Add the eval dataset
eval_dataset = CertifaiDataset('evaluation',
                               CertifaiDatasetSource.csv(preprocessed_dataset_file))
scan.add_dataset(eval_dataset)

# Setup an evaluation for fairness on the above dataset using the model
# We'll look at disparity between groups defined by age
age_grouping = CertifaiGroupingFeature('age',
                                       buckets=[
                                           CertifaiGroupingBucket('< 25', max=24),
                                           CertifaiGroupingBucket('25-49', max=49),
                                           CertifaiGroupingBucket('50+')
                                       ])
scan.add_fairness_grouping_feature(age_grouping)
scan.add_evaluation_type('fairness')
scan.evaluation_dataset_id = 'evaluation'

# Because the dataset contains a ground truth outcome column which the model does not
# expect to receive as input we need to state that in the dataset schema (since it cannot
# be inferred from the CSV)
scan.dataset_schema.outcome_feature_name = label_column

# Run the scan.
result = scan.run(write_reports=False)
# Out:
# Starting scan with model_use_case_id: 'test_user_case' and scan_id: 'c97f3b98fe34'
# [--------------------] 2020-06-09 14:54:45.006199 - 0 of 2 reports (0.0% complete) - Running fairness evaluation for model: SVM
# [##########----------] 2020-06-09 15:12:59.214070 - 1 of 2 reports (50.0% complete) - Running fairness evaluation for model: logistic
# [####################] 2020-06-09 15:22:41.551474 - 2 of 2 reports (100.0% complete) - Completed all evaluations

# %%
# The result is a dictionary keyed on analysis, containing reports keyed on model id
# The console app is the recommended way to view these, by saving the results to file
# (see previous cell), but programmatic analysis of the result here is also possible
df = construct_scores_dataframe(scores('fairness', result), include_confidence=True)
display(df)
# Out:
#                     context    type  overall fairness  \
# SVM (burden)            SVM  burden             78.28
# logistic (burden)  logistic  burden             78.04
#
#                    overall fairness lower bound  overall fairness upper bound  \
# SVM (burden)                              75.47                         80.92
# logistic (burden)                         75.26                         80.66
#
#                    Feature (age)  Feature (age) lower bound  \
# SVM (burden)               78.28                      75.47
# logistic (burden)          78.04                      75.26
#
#                    Feature (age) upper bound  Group details (25-49)  \
# SVM (burden)                           80.92                   0.18
# logistic (burden)                      80.66                   0.15
#
#                    Group details (25-49) lower bound  \
# SVM (burden)                                    0.16
# logistic (burden)                               0.14
#
#                    Group details (25-49) upper bound  Group details (50+)  \
# SVM (burden)                                    0.20                 0.15
# logistic (burden)                               0.17                 0.13
#
#                    Group details (50+) lower bound  \
# SVM (burden)                                  0.14
# logistic (burden)                             0.12
#
#                    Group details (50+) upper bound  Group details (< 25)  \
# SVM (burden)                                  0.17                  0.28
# logistic (burden)                             0.15                  0.25
#
#                    Group details (< 25) lower bound  \
# SVM (burden)                                   0.27
# logistic (burden)                              0.24
#
#                    Group details (< 25) upper bound
# SVM (burden)                                   0.33
# logistic (burden)                              0.28

# %%
# Many scores also come with 95% confidence bounds, which we omitted above for the sake of brevity, but
# we can include those also.  In the example here we include the confidence bounds but only display the scores
# to a reduced level of detail to keep a smallish table for display purposes
df = construct_scores_dataframe(scores('fairness', result, max_depth=1))

display(df)

print("\n")

# Let's chart the fairness measure by age-group for each model together with its confidence bounds for
# easier visual comparison:
# %matplotlib inline
import matplotlib.pyplot as plt

groups = ['< 25', '25-49', '50+']
feature_scores = df[[f"Group details ({g})" for g in groups]]
feature_lower_bounds = df[[f + ' lower bound' for f in feature_scores]]
feature_upper_bounds = df[[f + ' upper bound' for f in feature_scores]]

fig, ax = plt.subplots(figsize=[12,4])
ax.set_title('Age burdens by model', fontsize=20)
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:pink']
width = 0.4

ax.set_xticks(np.arange(len(groups))+width)
ax.set_xticklabels(groups)

for idx in range(len(df)):
    central_values = list(feature_scores.iloc[idx])
    lower_bounds = list(feature_lower_bounds.iloc[idx])
    upper_bounds = list(feature_upper_bounds.iloc[idx])
    lower_errors = [central_values[i] - lower_bounds[i] for i in range(len(central_values))]
    upper_errors = [upper_bounds[i] - central_values[i] for i in range(len(central_values))]

    ax.bar([width/2+idx*width+f_idx for f_idx in range(len(groups))],
            central_values,
            width,
            yerr=[lower_errors, upper_errors],
            color=colors[idx],
            label=df.index[idx],
            capsize=10)

fig.legend(fontsize=14, bbox_to_anchor=(1.1,.6))
fig.tight_layout()
fig.subplots_adjust(right=0.8) 
plt.show()
# Out:
#                     context    type  overall fairness  \
# SVM (burden)            SVM  burden             78.28
# logistic (burden)  logistic  burden             78.04
#
#                    overall fairness lower bound  overall fairness upper bound  \
# SVM (burden)                              75.47                         80.92
# logistic (burden)                         75.26                         80.66
#
#                    Feature (age)  Feature (age) lower bound  \
# SVM (burden)               78.28                      75.47
# logistic (burden)          78.04                      75.26
#
#                    Feature (age) upper bound  Group details (25-49)  \
# SVM (burden)                           80.92                   0.18
# logistic (burden)                      80.66                   0.15
#
#                    Group details (25-49) lower bound  \
# SVM (burden)                                    0.16
# logistic (burden)                               0.14
#
#                    Group details (25-49) upper bound  Group details (50+)  \
# SVM (burden)                                    0.20                 0.15
# logistic (burden)                               0.17                 0.13
#
#                    Group details (50+) lower bound  \
# SVM (burden)                                  0.14
# logistic (burden)                             0.12
#
#                    Group details (50+) upper bound  Group details (< 25)  \
# SVM (burden)                                  0.17                  0.28
# logistic (burden)                             0.15                  0.25
#
#                    Group details (< 25) lower bound  \
# SVM (burden)                                   0.27
# logistic (burden)                              0.24
#
#                    Group details (< 25) upper bound
# SVM (burden)                                   0.33
# logistic (burden)                              0.28

# %% [markdown]
# ## Conclusion
#
# As we can see from the above chart, it's much harder for young people to achieve a high income than it is
# for older cohorts.  This is not unexpected, but it's reassuring to see it confirmed.  It is also apparent that
# the logistic model is giving slightly less biased results than is the SVM, and since both models had similar accuracy it would probably be our better choice here.
